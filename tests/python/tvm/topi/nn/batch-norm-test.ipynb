# %%
import tvm

import tvm.te as te

from tvm.script import ir as I
from tvm.script import tir as T
from tvm.script import relax as R


def showmod(mod: tvm.ir.module.IRModule):
    mod.show(
        black_format=True,
        show_meta=False,
        verbose_expr=True,
        show_object_address=False,
        show_all_struct_info=True,
    )


def createandshowmod(ops):
    te_func = te.create_prim_func(ops).with_attrs({"global_symbol": "test"})
    mod = tvm.IRModule({"test": te_func})
    showmod(mod)


from tvm.topi.nn.batch_norm import *

# %% [markdown]
# #### batch_norm
# $y = \frac{x-E[x]}{\sqrt{Var[x]+\epsilon}} * \gamma + \beta$

# %%
data: tvm.te.Tensor = te.placeholder(shape=(128, 128), dtype="float32", name="data")
gamma: tvm.te.Tensor = te.placeholder(shape=(128, 128), dtype="float32", name="gamma")
beta: tvm.te.Tensor = te.placeholder(shape=(128, 128), dtype="float32", name="beta")
moving_mean: tvm.te.Tensor = te.placeholder(
    shape=(128, 128), dtype="float32", name="moving_mean"
)
moving_var: tvm.te.Tensor = te.placeholder(
    shape=(128, 128), dtype="float32", name="moving_var"
)
axis = 0
epsilon = 1e-5
center = False
scale = True
training = False
momentum = 0.1

output, output_moving_mean, output_moving_var = batch_norm(
    data,
    gamma,
    beta,
    moving_mean,
    moving_var,
    axis,
    epsilon,
    center,
    scale,
    training,
    momentum,
)

createandshowmod(
    [
        data,
        gamma,
        beta,
        moving_mean,
        moving_var,
        output,
        output_moving_mean,
        output_moving_var,
    ]
)
# Out:
# <div class="highlight" style="background: "><pre style="line-height: 125%;"><span></span><span style="color: #007979; font-style: italic"># from tvm.script import ir as I</span>
# <span style="color: #007979; font-style: italic"># from tvm.script import tir as T</span>
#
#
# <span style="color: #A2F">@I</span><span style="color: #A2F; font-weight: bold">.</span>ir_module
# <span style="color: #008000; font-weight: bold">class</span> <span style="color: #00F; font-weight: bold">Module</span>:
#     <span style="color: #A2F">@T</span><span style="color: #A2F; font-weight: bold">.</span>prim_func
#     <span style="color: #008000; font-weight: bold">def</span> <span style="color: #00F">test</span>(
#         data: T<span style="color: #A2F; font-weight: bold">.</span>Buffer((<span style="color: #008000">128</span>, <span style="color: #008000">128</span>), <span style="color: #BA2121">&quot;float32&quot;</span>),
#         gamma: T<span style="color: #A2F; font-weight: bold">.</span>Buffer((<span style="color: #008000">128</span>, <span style="color: #008000">128</span>), <span style="color: #BA2121">&quot;float32&quot;</span>),
#         beta: T<span style="color: #A2F; font-weight: bold">.</span>Buffer((<span style="color: #008000">128</span>, <span style="color: #008000">128</span>), <span style="color: #BA2121">&quot;float32&quot;</span>),
#         moving_mean: T<span style="color: #A2F; font-weight: bold">.</span>Buffer((<span style="color: #008000">128</span>, <span style="color: #008000">128</span>), <span style="color: #BA2121">&quot;float32&quot;</span>),
#         moving_var: T<span style="color: #A2F; font-weight: bold">.</span>Buffer((<span style="color: #008000">128</span>, <span style="color: #008000">128</span>), <span style="color: #BA2121">&quot;float32&quot;</span>),
#         T_multiply: T<span style="color: #A2F; font-weight: bold">.</span>Buffer((<span style="color: #008000">128</span>, <span style="color: #008000">128</span>), <span style="color: #BA2121">&quot;float32&quot;</span>),
#         T_multiply_1: T<span style="color: #A2F; font-weight: bold">.</span>Buffer((<span style="color: #008000">128</span>, <span style="color: #008000">128</span>), <span style="color: #BA2121">&quot;float32&quot;</span>),
#         T_multiply_2: T<span style="color: #A2F; font-weight: bold">.</span>Buffer((<span style="color: #008000">128</span>, <span style="color: #008000">128</span>), <span style="color: #BA2121">&quot;float32&quot;</span>),
#     ):
#         T<span style="color: #A2F; font-weight: bold">.</span>func_attr({<span style="color: #BA2121">&quot;tir.noalias&quot;</span>: T<span style="color: #A2F; font-weight: bold">.</span>bool(<span style="color: #008000; font-weight: bold">True</span>)})
#         <span style="color: #007979; font-style: italic"># with T.block(&quot;root&quot;):</span>
#         data_red <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>alloc_buffer((<span style="color: #008000">128</span>,))
#         T_divide <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>alloc_buffer((<span style="color: #008000">128</span>,))
#         T_reshape <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>alloc_buffer((<span style="color: #008000">128</span>, <span style="color: #008000">1</span>))
#         T_subtract <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>alloc_buffer((<span style="color: #008000">128</span>, <span style="color: #008000">128</span>))
#         T_subtract_1 <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>alloc_buffer((<span style="color: #008000">128</span>, <span style="color: #008000">128</span>))
#         T_subtract_2 <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>alloc_buffer((<span style="color: #008000">128</span>, <span style="color: #008000">128</span>))
#         T_multiply_3 <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>alloc_buffer((<span style="color: #008000">128</span>, <span style="color: #008000">128</span>))
#         T_multiply_red <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>alloc_buffer((<span style="color: #008000">128</span>,))
#         T_divide_1 <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>alloc_buffer((<span style="color: #008000">128</span>,))
#         T_reshape_1 <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>alloc_buffer((<span style="color: #008000">128</span>, <span style="color: #008000">1</span>))
#         T_add <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>alloc_buffer((<span style="color: #008000">128</span>, <span style="color: #008000">1</span>))
#         compute <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>alloc_buffer((<span style="color: #008000">128</span>, <span style="color: #008000">1</span>))
#         T_divide_2 <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>alloc_buffer((<span style="color: #008000">128</span>, <span style="color: #008000">128</span>))
#         T_reshape_2 <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>alloc_buffer((<span style="color: #008000">128</span>, <span style="color: #008000">1</span>))
#         <span style="color: #008000; font-weight: bold">for</span> ax0, k1 <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #A2F; font-weight: bold">.</span>grid(<span style="color: #008000">128</span>, <span style="color: #008000">128</span>):
#             <span style="color: #008000; font-weight: bold">with</span> T<span style="color: #A2F; font-weight: bold">.</span>block(<span style="color: #BA2121">&quot;data_red&quot;</span>):
#                 v_ax0, v_k1 <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>axis<span style="color: #A2F; font-weight: bold">.</span>remap(<span style="color: #BA2121">&quot;SR&quot;</span>, [ax0, k1])
#                 T<span style="color: #A2F; font-weight: bold">.</span>reads(data[v_ax0, v_k1])
#                 T<span style="color: #A2F; font-weight: bold">.</span>writes(data_red[v_ax0])
#                 <span style="color: #008000; font-weight: bold">with</span> T<span style="color: #A2F; font-weight: bold">.</span>init():
#                     data_red[v_ax0] <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>float32(<span style="color: #008000">0.0</span>)
#                 data_red[v_ax0] <span style="color: #A2F; font-weight: bold">=</span> data_red[v_ax0] <span style="color: #A2F; font-weight: bold">+</span> data[v_ax0, v_k1]
#         <span style="color: #008000; font-weight: bold">for</span> ax0 <span style="color: #008000; font-weight: bold">in</span> range(<span style="color: #008000">128</span>):
#             <span style="color: #008000; font-weight: bold">with</span> T<span style="color: #A2F; font-weight: bold">.</span>block(<span style="color: #BA2121">&quot;T_divide&quot;</span>):
#                 v_ax0 <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>axis<span style="color: #A2F; font-weight: bold">.</span>spatial(<span style="color: #008000">128</span>, ax0)
#                 T<span style="color: #A2F; font-weight: bold">.</span>reads(data_red[v_ax0])
#                 T<span style="color: #A2F; font-weight: bold">.</span>writes(T_divide
