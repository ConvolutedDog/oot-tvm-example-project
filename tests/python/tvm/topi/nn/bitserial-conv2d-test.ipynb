# %%
import tvm

from tvm.script import ir as I
from tvm.script import tir as T
from tvm.script import relax as R


def showmod(mod: tvm.ir.module.IRModule):
    mod.show(
        black_format=True,
        show_meta=False,
        verbose_expr=True,
        show_object_address=False,
        show_all_struct_info=True,
    )


def createandshowmod(ops):
    te_func = te.create_prim_func(ops).with_attrs({"global_symbol": "test"})
    mod = tvm.IRModule({"test": te_func})
    showmod(mod)


from tvm.topi.nn.bitserial_conv2d import *

# %% [markdown]
# #### bitserial_conv2d_nchw

# %%
data: te.Tensor = te.placeholder(
    (16, 8, 224, 224), dtype="uint8", name="data"
)  # 8 bits
kernel: te.Tensor = te.placeholder(
    (64, 8, 4, 4), dtype="uint8", name="kernel"
)  # 8 bits
stride = (3, 3)
padding = (1, 1)
activation_bits = 4
weight_bits = 4
out_dtype = "uint8"
pack_dtype = "uint8"
unipolar = True

output = bitserial_conv2d_nchw(
    data,
    kernel,
    stride,
    padding,
    activation_bits,
    weight_bits,
    pack_dtype,
    out_dtype,
    unipolar,
)

createandshowmod([data, kernel, output])
# Out:
# <div class="highlight" style="background: "><pre style="line-height: 125%;"><span></span><span style="color: #007979; font-style: italic"># from tvm.script import ir as I</span>
# <span style="color: #007979; font-style: italic"># from tvm.script import tir as T</span>
#
#
# <span style="color: #A2F">@I</span><span style="color: #A2F; font-weight: bold">.</span>ir_module
# <span style="color: #008000; font-weight: bold">class</span> <span style="color: #00F; font-weight: bold">Module</span>:
#     <span style="color: #A2F">@T</span><span style="color: #A2F; font-weight: bold">.</span>prim_func
#     <span style="color: #008000; font-weight: bold">def</span> <span style="color: #00F">test</span>(
#         data: T<span style="color: #A2F; font-weight: bold">.</span>Buffer((<span style="color: #008000">16</span>, <span style="color: #008000">8</span>, <span style="color: #008000">224</span>, <span style="color: #008000">224</span>), <span style="color: #BA2121">&quot;uint8&quot;</span>),
#         kernel: T<span style="color: #A2F; font-weight: bold">.</span>Buffer((<span style="color: #008000">64</span>, <span style="color: #008000">8</span>, <span style="color: #008000">4</span>, <span style="color: #008000">4</span>), <span style="color: #BA2121">&quot;uint8&quot;</span>),
#         Conv2dOutput: T<span style="color: #A2F; font-weight: bold">.</span>Buffer((<span style="color: #008000">16</span>, <span style="color: #008000">64</span>, <span style="color: #008000">75</span>, <span style="color: #008000">75</span>), <span style="color: #BA2121">&quot;uint8&quot;</span>),
#     ):
#         T<span style="color: #A2F; font-weight: bold">.</span>func_attr({<span style="color: #BA2121">&quot;tir.noalias&quot;</span>: T<span style="color: #A2F; font-weight: bold">.</span>bool(<span style="color: #008000; font-weight: bold">True</span>)})
#         <span style="color: #007979; font-style: italic"># with T.block(&quot;root&quot;):</span>
#         QuantizeInput_v0 <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>alloc_buffer((<span style="color: #008000">16</span>, <span style="color: #008000">1</span>, <span style="color: #008000">1</span>, <span style="color: #008000">224</span>, <span style="color: #008000">224</span>), <span style="color: #BA2121">&quot;uint8&quot;</span>)
#         QuantizeInput_v1 <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>alloc_buffer((<span style="color: #008000">16</span>, <span style="color: #008000">1</span>, <span style="color: #008000">1</span>, <span style="color: #008000">224</span>, <span style="color: #008000">224</span>), <span style="color: #BA2121">&quot;uint8&quot;</span>)
#         QuantizeInput_v2 <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>alloc_buffer((<span style="color: #008000">16</span>, <span style="color: #008000">1</span>, <span style="color: #008000">1</span>, <span style="color: #008000">224</span>, <span style="color: #008000">224</span>), <span style="color: #BA2121">&quot;uint8&quot;</span>)
#         QuantizeInput_v3 <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>alloc_buffer((<span style="color: #008000">16</span>, <span style="color: #008000">1</span>, <span style="color: #008000">1</span>, <span style="color: #008000">224</span>, <span style="color: #008000">224</span>), <span style="color: #BA2121">&quot;uint8&quot;</span>)
#         T_concat <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>alloc_buffer((<span style="color: #008000">16</span>, <span style="color: #008000">1</span>, <span style="color: #008000">4</span>, <span style="color: #008000">224</span>, <span style="color: #008000">224</span>), <span style="color: #BA2121">&quot;uint8&quot;</span>)
#         pad_temp <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>alloc_buffer((<span style="color: #008000">16</span>, <span style="color: #008000">1</span>, <span style="color: #008000">4</span>, <span style="color: #008000">226</span>, <span style="color: #008000">226</span>), <span style="color: #BA2121">&quot;uint8&quot;</span>)
#         QuantizeInput_v0_1 <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>alloc_buffer((<span style="color: #008000">64</span>, <span style="color: #008000">1</span>, <span style="color: #008000">4</span>, <span style="color: #008000">4</span>, <span style="color: #008000">1</span>), <span style="color: #BA2121">&quot;uint8&quot;</span>)
#         QuantizeInput_v1_1 <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>alloc_buffer((<span style="color: #008000">64</span>, <span style="color: #008000">1</span>, <span style="color: #008000">4</span>, <span style="color: #008000">4</span>, <span style="color: #008000">1</span>), <span style="color: #BA2121">&quot;uint8&quot;</span>)
#         QuantizeInput_v2_1 <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>alloc_buffer((<span style="color: #008000">64</span>, <span style="color: #008000">1</span>, <span style="color: #008000">4</span>, <span style="color: #008000">4</span>, <span style="color: #008000">1</span>), <span style="color: #BA2121">&quot;uint8&quot;</span>)
#         QuantizeInput_v3_1 <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>alloc_buffer((<span style="color: #008000">64</span>, <span style="color: #008000">1</span>, <span style="color: #008000">4</span>, <span style="color: #008000">4</span>, <span style="color: #008000">1</span>), <span style="color: #BA2121">&quot;uint8&quot;</span>)
#         T_concat_1 <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>alloc_buffer((<span style="color: #008000">64</span>, <span style="color: #008000">1</span>, <span style="color: #008000">4</span>, <span style="color: #008000">4</span>, <span style="color: #008000">4</span>), <span style="color: #BA2121">&quot;uint8&quot;</span>)
#         <span style="color: #008000; font-weight: bold">for</span> i0, i1, i2, i3, i4 <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #A2F; font-weight: bold">.</span>grid(<span style="color: #008000">16</span>, <span style="color: #008000">1</span>, <span style="color: #008000">1</span>, <span style="color: #008000">224</span>, <span style="color: #008000">224</span>):
#             <span style="color: #008000; font-weight: bold">with</span> T<span style="color: #A2F; font-weight: bold">.</span>block(<span style="color: #BA2121">&quot;QuantizeInput_v0&quot;</span>):
#                 v_i0, v_i1, v_i2, v_i3, v_i4 <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>axis<span style="color: #A2F; font-weight: bold">.</span>remap(
#                     <span style="color: #BA2121">&quot;SSSSS&quot;</span>, [i0, i1, i2, i3, i4]
#                 )
#                 T<span style="color: #A2F; font-weight: bold">.</span>reads(data[v_i0, v_i1 <span style="color: #A2F; font-weight: bold">*</span> <span style="color: #008000">8</span> : v_i1 <span style="color: #A2F; font-weight: bold">*</span> <span style="color: #008000">8</span> <span style="color: #A2F; font-weight: bold">+</span> <span style="color: #008000">8</span>, v_i3, v_i4])
#                 T<span style="color: #A2F; font-weight: bold">.</span>writes(QuantizeInput_v0[v_i0, v_i1, v_i2, v_i3, v_i4])
#                 QuantizeInput_v0[v_i0, v_i1, v_i2, v_i3, v_i4] <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>bitwise_or(
#                     T<span st

# %% [markdown]
# #### bitserial_conv2d_nhwc

# %%
data: te.Tensor = te.placeholder((16, 224, 224, 8), dtype="uint8", name="data")
kernel: te.Tensor = te.placeholder((4, 4, 8, 64), dtype="uint8", name="kernel")
stride = (3, 3)
padding = (1, 1)
activation_bits = 4
weight_bits = 4
out_dtype = "uint8"
pack_dtype = "uint8"
unipolar = True

output = bitserial_conv2d_nhwc(
    data,
    kernel,
    stride,
    padding,
    activation_bits,
    weight_bits,
    pack_dtype,
    out_dtype,
    unipolar,
)

createandshowmod([data, kernel, output])
# Out:
# <div class="highlight" style="background: "><pre style="line-height: 125%;"><span></span><span style="color: #007979; font-style: italic"># from tvm.script import ir as I</span>
# <span style="color: #007979; font-style: italic"># from tvm.script import tir as T</span>
#
#
# <span style="color: #A2F">@I</span><span style="color: #A2F; font-weight: bold">.</span>ir_module
# <span style="color: #008000; font-weight: bold">class</span> <span style="color: #00F; font-weight: bold">Module</span>:
#     <span style="color: #A2F">@T</span><span style="color: #A2F; font-weight: bold">.</span>prim_func
#     <span style="color: #008000; font-weight: bold">def</span> <span style="color: #00F">test</span>(
#         data: T<span style="color: #A2F; font-weight: bold">.</span>Buffer((<span style="color: #008000">16</span>, <span style="color: #008000">224</span>, <span style="color: #008000">224</span>, <span style="color: #008000">8</span>), <span style="color: #BA2121">&quot;uint8&quot;</span>),
#         kernel: T<span style="color: #A2F; font-weight: bold">.</span>Buffer((<span style="color: #008000">4</span>, <span style="color: #008000">4</span>, <span style="color: #008000">8</span>, <span style="color: #008000">64</span>), <span style="color: #BA2121">&quot;uint8&quot;</span>),
#         Conv2dOutput: T<span style="color: #A2F; font-weight: bold">.</span>Buffer((<span style="color: #008000">16</span>, <span style="color: #008000">75</span>, <span style="color: #008000">75</span>, <span style="color: #008000">64</span>), <span style="color: #BA2121">&quot;uint8&quot;</span>),
#     ):
#         T<span style="color: #A2F; font-weight: bold">.</span>func_attr({<span style="color: #BA2121">&quot;tir.noalias&quot;</span>: T<span style="color: #A2F; font-weight: bold">.</span>bool(<span style="color: #008000; font-weight: bold">True</span>)})
#         <span style="color: #007979; font-style: italic"># with T.block(&quot;root&quot;):</span>
#         QuantizeInput_v0 <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>alloc_buffer((<span style="color: #008000">16</span>, <span style="color: #008000">224</span>, <span style="color: #008000">224</span>, <span style="color: #008000">1</span>, <span style="color: #008000">1</span>), <span style="color: #BA2121">&quot;uint8&quot;</span>)
#         QuantizeInput_v1 <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>alloc_buffer((<span style="color: #008000">16</span>, <span style="color: #008000">224</span>, <span style="color: #008000">224</span>, <span style="color: #008000">1</span>, <span style="color: #008000">1</span>), <span style="color: #BA2121">&quot;uint8&quot;</span>)
#         QuantizeInput_v2 <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>alloc_buffer((<span style="color: #008000">16</span>, <span style="color: #008000">224</span>, <span style="color: #008000">224</span>, <span style="color: #008000">1</span>, <span style="color: #008000">1</span>), <span style="color: #BA2121">&quot;uint8&quot;</span>)
#         QuantizeInput_v3 <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>alloc_buffer((<span style="color: #008000">16</span>, <span style="color: #008000">224</span>, <span style="color: #008000">224</span>, <span style="color: #008000">1</span>, <span style="color: #008000">1</span>), <span style="color: #BA2121">&quot;uint8&quot;</span>)
#         T_concat <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>alloc_buffer((<span style="color: #008000">16</span>, <span style="color: #008000">224</span>, <span style="color: #008000">224</span>, <span style="color: #008000">1</span>, <span style="color: #008000">4</span>), <span style="color: #BA2121">&quot;uint8&quot;</span>)
#         PaddedInput <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>alloc_buffer((<span style="color: #008000">16</span>, <span style="color: #008000">226</span>, <span style="color: #008000">226</span>, <span style="color: #008000">1</span>, <span style="color: #008000">4</span>), <span style="color: #BA2121">&quot;uint8&quot;</span>)
#         QuantizeInput_v0_1 <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>alloc_buffer((<span style="color: #008000">4</span>, <span style="color: #008000">4</span>, <span style="color: #008000">1</span>, <span style="color: #008000">64</span>, <span style="color: #008000">1</span>), <span style="color: #BA2121">&quot;uint8&quot;</span>)
#         QuantizeInput_v1_1 <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>alloc_buffer((<span style="color: #008000">4</span>, <span style="color: #008000">4</span>, <span style="color: #008000">1</span>, <span style="color: #008000">64</span>, <span style="color: #008000">1</span>), <span style="color: #BA2121">&quot;uint8&quot;</span>)
#         QuantizeInput_v2_1 <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>alloc_buffer((<span style="color: #008000">4</span>, <span style="color: #008000">4</span>, <span style="color: #008000">1</span>, <span style="color: #008000">64</span>, <span style="color: #008000">1</span>), <span style="color: #BA2121">&quot;uint8&quot;</span>)
#         QuantizeInput_v3_1 <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>alloc_buffer((<span style="color: #008000">4</span>, <span style="color: #008000">4</span>, <span style="color: #008000">1</span>, <span style="color: #008000">64</span>, <span style="color: #008000">1</span>), <span style="color: #BA2121">&quot;uint8&quot;</span>)
#         T_concat_1 <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>alloc_buffer((<span style="color: #008000">4</span>, <span style="color: #008000">4</span>, <span style="color: #008000">1</span>, <span style="color: #008000">64</span>, <span style="color: #008000">4</span>), <span style="color: #BA2121">&quot;uint8&quot;</span>)
#         <span style="color: #008000; font-weight: bold">for</span> i0, i1, i2, i3, i4 <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #A2F; font-weight: bold">.</span>grid(<span style="color: #008000">16</span>, <span style="color: #008000">224</span>, <span style="color: #008000">224</span>, <span style="color: #008000">1</span>, <span style="color: #008000">1</span>):
#             <span style="color: #008000; font-weight: bold">with</span> T<span style="color: #A2F; font-weight: bold">.</span>block(<span style="color: #BA2121">&quot;QuantizeInput_v0&quot;</span>):
#                 v_i0, v_i1, v_i2, v_i3, v_i4 <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>axis<span style="color: #A2F; font-weight: bold">.</span>remap(
#                     <span style="color: #BA2121">&quot;SSSSS&quot;</span>, [i0, i1, i2, i3, i4]
#                 )
#                 T<span style="color: #A2F; font-weight: bold">.</span>reads(data[v_i0, v_i1, v_i2, v_i3 <span style="color: #A2F; font-weight: bold">*</span> <span style="color: #008000">8</span> : v_i3 <span style="color: #A2F; font-weight: bold">*</span> <span style="color: #008000">8</span> <span style="color: #A2F; font-weight: bold">+</span> <span style="color: #008000">8</span>])
#                 T<span style="color: #A2F; font-weight: bold">.</span>writes(QuantizeInput_v0[v_i0, v_i1, v_i2, v_i3, v_i4])
#                 QuantizeInput_v0[v_i0, v_i1, v_i2, v_i3, v_i4] <span style="color: #A2F; font-weight: bold">=</span> T<span style="color: #A2F; font-weight: bold">.</span>bitwise_or(
#                     T<span
